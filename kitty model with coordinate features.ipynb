# %%
import os
import cv2
import pandas as pd
import time
from PIL import Image
import numpy as np
import mediapipe as mp 
mpPose = mp.solutions.pose
pose = mpPose.Pose()
mpDraw = mp.solutions.drawing_utils # For drawing keypoints
points = mpPose.PoseLandmark # points will have all 33 landmarks like nose, eyes, ears etc.

# %%
data = list()
data.append('Image')
data.append('label')
rootdir = "/home/shikha/POSEESTIMATION/TRAIN"

# %%
for p in points: #p will iterate through nose, eyes, ears etc...
        x = str(p)[13:]
        data.append(x + "_x") #will append nose_x
        data.append(x + "_y") #will append nose_y
        data.append(x + "_z") #will append nose_z
        data.append(x + "_vis") #will append nose_vis
train_data = pd.DataFrame(columns = data)
num_images=0

# %%
data
# Out:
# ['Image',
#  'label',
#  'NOSE_x',
#  'NOSE_y',
#  'NOSE_z',
#  'NOSE_vis',
#  'LEFT_EYE_INNER_x',
#  'LEFT_EYE_INNER_y',
#  'LEFT_EYE_INNER_z',
#  'LEFT_EYE_INNER_vis',
#  'LEFT_EYE_x',
#  'LEFT_EYE_y',
#  'LEFT_EYE_z',
#  'LEFT_EYE_vis',
#  'LEFT_EYE_OUTER_x',
#  'LEFT_EYE_OUTER_y',
#  'LEFT_EYE_OUTER_z',
#  'LEFT_EYE_OUTER_vis',
#  'RIGHT_EYE_INNER_x',
#  'RIGHT_EYE_INNER_y',
#  'RIGHT_EYE_INNER_z',
#  'RIGHT_EYE_INNER_vis',
#  'RIGHT_EYE_x',
#  'RIGHT_EYE_y',
#  'RIGHT_EYE_z',
#  'RIGHT_EYE_vis',
#  'RIGHT_EYE_OUTER_x',
#  'RIGHT_EYE_OUTER_y',
#  'RIGHT_EYE_OUTER_z',
#  'RIGHT_EYE_OUTER_vis',
#  'LEFT_EAR_x',
#  'LEFT_EAR_y',
#  'LEFT_EAR_z',
#  'LEFT_EAR_vis',
#  'RIGHT_EAR_x',
#  'RIGHT_EAR_y',
#  'RIGHT_EAR_z',
#  'RIGHT_EAR_vis',
#  'MOUTH_LEFT_x',
#  'MOUTH_LEFT_y',
#  'MOUTH_LEFT_z',
#  'MOUTH_LEFT_vis',
#  'MOUTH_RIGHT_x',
#  'MOUTH_RIGHT_y',
#  'MOUTH_RIGHT_z',
#  'MOUTH_RIGHT_vis',
#  'LEFT_SHOULDER_x',
#  'LEFT_SHOULDER_y',
#  'LEFT_SHOULDER_z',
#  'LEFT_SHOULDER_vis',
#  'RIGHT_SHOULDER_x',
#  'RIGHT_SHOULDER_y',
#  'RIGHT_SHOULDER_z',
#  'RIGHT_SHOULDER_vis',
#  'LEFT_ELBOW_x',
#  'LEFT_ELBOW_y',
#  'LEFT_ELBOW_z',
#  'LEFT_ELBOW_vis',
#  'RIGHT_ELBOW_x',
#  'RIGHT_ELBOW_y',
#  'RIGHT_ELBOW_z',
#  'RIGHT_ELBOW_vis',
#  'LEFT_WRIST_x',
#  'LEFT_WRIST_y',
#  'LEFT_WRIST_z',
#  'LEFT_WRIST_vis',
#  'RIGHT_WRIST_x',
#  'RIGHT_WRIST_y',
#  'RIGHT_WRIST_z',
#  'RIGHT_WRIST_vis',
#  'LEFT_PINKY_x',
#  'LEFT_PINKY_y',
#  'LEFT_PINKY_z',
#  'LEFT_PINKY_vis',
#  'RIGHT_PINKY_x',
#  'RIGHT_PINKY_y',
#  'RIGHT_PINKY_z',
#  'RIGHT_PINKY_vis',
#  'LEFT_INDEX_x',
#  'LEFT_INDEX_y',
#  'LEFT_INDEX_z',
#  'LEFT_INDEX_vis',
#  'RIGHT_INDEX_x',
#  'RIGHT_INDEX_y',
#  'RIGHT_INDEX_z',
#  'RIGHT_INDEX_vis',
#  'LEFT_THUMB_x',
#  'LEFT_THUMB_y',
#  'LEFT_THUMB_z',
#  'LEFT_THUMB_vis',
#  'RIGHT_THUMB_x',
#  'RIGHT_THUMB_y',
#  'RIGHT_THUMB_z',
#  'RIGHT_THUMB_vis',
#  'LEFT_HIP_x',
#  'LEFT_HIP_y',
#  'LEFT_HIP_z',
#  'LEFT_HIP_vis',
#  'RIGHT_HIP_x',
#  'RIGHT_HIP_y',
#  'RIGHT_HIP_z',
#  'RIGHT_HIP_vis',
#  'LEFT_KNEE_x',
#  'LEFT_KNEE_y',
#  'LEFT_KNEE_z',
#  'LEFT_KNEE_vis',
#  'RIGHT_KNEE_x',
#  'RIGHT_KNEE_y',
#  'RIGHT_KNEE_z',
#  'RIGHT_KNEE_vis',
#  'LEFT_ANKLE_x',
#  'LEFT_ANKLE_y',
#  'LEFT_ANKLE_z',
#  'LEFT_ANKLE_vis',
#  'RIGHT_ANKLE_x',
#  'RIGHT_ANKLE_y',
#  'RIGHT_ANKLE_z',
#  'RIGHT_ANKLE_vis',
#  'LEFT_HEEL_x',
#  'LEFT_HEEL_y',
#  'LEFT_HEEL_z',
#  'LEFT_HEEL_vis',
#  'RIGHT_HEEL_x',
#  'RIGHT_HEEL_y',
#  'RIGHT_HEEL_z',
#  'RIGHT_HEEL_vis',
#  'LEFT_FOOT_INDEX_x',
#  'LEFT_FOOT_INDEX_y',
#  'LEFT_FOOT_INDEX_z',
#  'LEFT_FOOT_INDEX_vis',
#  'RIGHT_FOOT_INDEX_x',
#  'RIGHT_FOOT_INDEX_y',
#  'RIGHT_FOOT_INDEX_z',
#  'RIGHT_FOOT_INDEX_vis']

# %%
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        try:
            temp=[]     
            imagename=os.path.basename(subdir)
            img = cv2.imread(rootdir + "/" +imagename+"/" +file)
            imageWidth, imageHeight = img.shape[:2]
            imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            temp.append(subdir)
            temp.append(imagename)
            results = pose.process(imgRGB)
            if results.pose_landmarks:
                    mpDraw.draw_landmarks(img, results.pose_landmarks, mpPose.POSE_CONNECTIONS) #draw landmarks on image
                    landmarks = results.pose_landmarks.landmark
                    for i,j in zip(points,landmarks):
                            temp = temp + [j.x, j.y, j.z, j.visibility]
            train_data.loc[num_images] = temp
            num_images += 1
        
        except ValueError as ve:
            continue 
train_data.to_csv("train_converted.csv", index=False)

# %%
train_data
# Out:
#                                           Image    label    NOSE_x    NOSE_y  \
# 0     /home/shikha/POSEESTIMATION/TRAIN/goddess  goddess  0.535455  0.136854
# 1     /home/shikha/POSEESTIMATION/TRAIN/goddess  goddess  0.495051  0.169287
# 2     /home/shikha/POSEESTIMATION/TRAIN/goddess  goddess  0.632244  0.313259
# 3     /home/shikha/POSEESTIMATION/TRAIN/goddess  goddess  0.486969  0.345291
# 4     /home/shikha/POSEESTIMATION/TRAIN/goddess  goddess  0.573624  0.221728
# ...                                         ...      ...       ...       ...
# 1123    /home/shikha/POSEESTIMATION/TRAIN/plank    plank  0.732491  1.051557
# 1124    /home/shikha/POSEESTIMATION/TRAIN/plank    plank  0.480266  0.434851
# 1125    /home/shikha/POSEESTIMATION/TRAIN/plank    plank  0.857005  0.572440
# 1126    /home/shikha/POSEESTIMATION/TRAIN/plank    plank  0.669751  0.537460
# 1127    /home/shikha/POSEESTIMATION/TRAIN/plank    plank  0.367497  1.092489
#
#         NOSE_z  NOSE_vis  LEFT_EYE_INNER_x  LEFT_EYE_INNER_y  \
# 0    -0.417325  1.000000          0.532745          0.114784
# 1    -0.349709  1.000000          0.504998          0.145705
# 2    -0.471418  0.999988          0.640431          0.298225
# 3    -0.350539  0.999020          0.494720          0.339299
# 4    -0.382249  0.998384          0.581841          0.143272
# ...        ...       ...               ...               ...
# 1123 -0.398472  0.917057          0.741960          1.039853
# 1124 -0.459796  0.924841          0.530394          0.463188
# 1125 -0.086285  0.932266          0.889124          0.568714
# 1126  0.004413  0.924135          0.693213          0.550560
# 1127 -0.592048  0.877777          0.370457          1.062429
#
#       LEFT_EYE_INNER_z  LEFT_EYE_INNER_vis  ...  RIGHT_HEEL_z  RIGHT_HEEL_vis  \
# 0            -0.358633            1.000000  ...     -0.467017        0.993488
# 1            -0.311614            0.999999  ...     -0.126579        0.990839
# 2            -0.421868            0.999988  ...      0.150339        0.985076
# 3            -0.318293            0.998965  ...     -0.082002        0.949548
# 4            -0.394444            0.998441  ...      0.443720        0.904905
# ...                ...                 ...  ...           ...             ...
# 1123         -0.397660            0.910072  ...      0.709711        0.793321
# 1124         -0.450521            0.918668  ...      0.444482        0.715274
# 1125         -0.075609            0.926708  ...      0.169543        0.714255
# 1126          0.014235            0.919477  ...     -0.204727        0.695425
# 1127         -0.687515            0.882469  ...      1.877164        0.661934
#
#       LEFT_FOOT_INDEX_x  LEFT_FOOT_INDEX_y  LEFT_FOOT_INDEX_z  \
# 0              0.745426           0.912100          -0.272691
# 1              0.718080           0.901810          -0.322027
# 2              0.885885           0.971695          -0.207884
# 3              0.631436           0.812170          -0.281757
# 4              0.395049           0.863880           0.409994
# ...                 ...                ...                ...
# 1123          -0.050943           1.033161           0.823234
# 1124          -0.589964           0.579520           0.525798
# 1125          -0.237353           0.611387           0.509124
# 1126           0.309048           0.712542          -0.484677
# 1127          -0.158306           0.695897           1.920338
#
#       LEFT_FOOT_INDEX_vis  RIGHT_FOOT_INDEX_x  RIGHT_FOOT_INDEX_y  \
# 0                0.994928            0.215182            0.973529
# 1                0.990191            0.236205            0.911093
# 2                0.985713            0.313092            0.922302
# 3                0.958348            0.431479            0.812472
# 4                0.887255            0.559076            0.903645
# ...                   ...                 ...                 ...
# 1123             0.725770           -0.017161            0.914018
# 1124             0.662428           -0.608180            0.172754
# 1125             0.610360           -0.366129            0.552984
# 1126             0.606716            0.332031            0.416896
# 1127             0.562395           -0.169077            0.698436
#
#       RIGHT_FOOT_INDEX_z  RIGHT_FOOT_INDEX_vis
# 0              -0.698939              0.998522
# 1              -0.274880              0.995516
# 2               0.019012              0.988558
# 3              -0.278518              0.955983
# 4               0.474589              0.899603
# ...                  ...                   ...
# 1123            0.633591              0.770723
# 1124           -0.094343              0.696286
# 1125            0.073848              0.660811
# 1126           -0.302299              0.641928
# 1127            1.688619              0.604184
#
# [1128 rows x 134 columns]

# %%
from sklearn.svm import SVC
da = pd.read_csv("train_converted.csv")
X,Y= train_data.iloc[:,2:134],train_data['label']
model = SVC(kernel = 'poly')
model.fit(X,Y)
# Out:
# SVC(kernel='poly')

# %%
import pickle
Pkl_Filename = "coordinatemodel.pkl"  

with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(model, file)

# %%
test= list()
test.append('Image')
test.append('label')
testdir = "/home/shikha/POSEESTIMATION/TEST"

for p in points: #p will iterate through nose, eyes, ears etc...
        x = str(p)[13:]
        test.append(x + "_x")
        test.append(x + "_y")
        test.append(x + "_z")
        test.append(x + "_vis")
test_data = pd.DataFrame(columns = data)

# %%
test_images=0
for subdir, dirs, files in os.walk(testdir):
    for file in files:
        try:
            temp=[]   
            imagename_test=os.path.basename(subdir)
            img_test = cv2.imread(testdir + "/" +imagename_test+"/" +file)
            imageWidth, imageHeight = img_test.shape[:2]
            imgRGB = cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB)
            temp.append(subdir)
            temp.append(imagename_test)
            results = pose.process(imgRGB)
            if results.pose_landmarks:
                    mpDraw.draw_landmarks(img_test, results.pose_landmarks, mpPose.POSE_CONNECTIONS) #draw landmarks on image
                    landmarks = results.pose_landmarks.landmark
                    for i,j in zip(points,landmarks):
                            temp = temp + [j.x, j.y, j.z, j.visibility]
            test_data.loc[test_images] = temp
            test_images += 1
        
        except ValueError as ve:
            continue 
#test_data.to_csv("test_converted.csv", index=False)

# %%
print(subdir)
print(test_images)
# Out:
# /home/shikha/POSEESTIMATION/TEST/plank
# 462

# %%
S,T= test_data.iloc[:,2:134],test_data['label']
pred = model.predict(S)

# %%
print(pred)


# In[20]:


from sklearn.metrics import accuracy_score
accuracy_score(T,pred)
# Out:
# ['plank' 'warrior2' 'goddess' 'goddess' 'goddess' 'goddess' 'warrior2'
#  'plank' 'warrior2' 'goddess' 'warrior2' 'warrior2' 'goddess' 'warrior2'
#  'goddess' 'warrior2' 'warrior2' 'goddess' 'goddess' 'goddess' 'goddess'
#  'warrior2' 'warrior2' 'warrior2' 'goddess' 'goddess' 'warrior2' 'goddess'
#  'warrior2' 'goddess' 'goddess' 'goddess' 'goddess' 'goddess' 'warrior2'
#  'warrior2' 'goddess' 'goddess' 'goddess' 'warrior2' 'warrior2' 'plank'
#  'goddess' 'goddess' 'goddess' 'goddess' 'goddess' 'goddess' 'goddess'
#  'goddess' 'warrior2' 'goddess' 'goddess' 'goddess' 'goddess' 'goddess'
#  'goddess' 'plank' 'goddess' 'warrior2' 'goddess' 'goddess' 'goddess'
#  'goddess' 'goddess' 'warrior2' 'goddess' 'warrior2' 'goddess' 'goddess'
#  'warrior2' 'goddess' 'goddess' 'goddess' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'plank' 'tree' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'goddess' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'tree' 'tree' 'warrior2'
#  'goddess' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'goddess'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'goddess' 'warrior2' 'warrior2' 'warrior2' 'goddess'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'goddess' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2'
#  'warrior2' 'goddess' 'warrior2' 'warrior2' 'warrior2' 'goddess'
#  'warrior2' 'goddess' 'warrior2' 'warrior2' 'goddess' 'warrior2'
#  'warrior2' 'warrior2' 'warrior2' 'warrior2' 'warrior2' 'goddess' 'plank'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'plank' 'downdog'
#  'plank' 'plank' 'plank' 'plank' 'downdog' 'downdog' 'plank' 'plank'
#  'downdog' 'plank' 'downdog' 'downdog' 'plank' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog' 'downdog'
#  'downdog' 'downdog' 'downdog' 'downdog' 'tree' 'tree' 'plank' 'tree'
#  'tree' 'warrior2' 'warrior2' 'tree' 'tree' 'tree' 'tree' 'tree' 'tree'
#  'tree' 'tree' 'tree' 'warrior2' 'tree' 'no pose' 'warrior2' 'warrior2'
#  'tree' 'no pose' 'tree' 'tree' 'tree' 'tree' 'tree' 'tree' 'tree' 'tree'
#  'warrior2' 'tree' 'warrior2' 'warrior2' 'tree' 'tree' 'tree' 'tree'
#  'tree' 'tree' 'tree' 'tree' 'tree' 'warrior2' 'tree' 'goddess' 'tree'
#  'warrior2' 'warrior2' 'warrior2' 'no pose' 'tree' 'warrior2' 'tree'
#  'tree' 'tree' 'tree' 'tree' 'plank' 'tree' 'cobra' 'warrior2' 'tree'
#  'warrior2' 'tree' 'warrior2' 'cobra' 'no pose' 'no pose' 'cobra' 'cobra'
#  'plank' 'cobra' 'cobra' 'warrior2' 'cobra' 'cobra' 'cobra' 'cobra'
#  'cobra' 'cobra' 'cobra' 'cobra' 'cobra' 'cobra' 'cobra' 'cobra' 'cobra'
#  'cobra' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'cobra' 'plank' 'plank' 'plank' 'plank' 'warrior2'
#  'plank' 'plank' 'plank' 'goddess' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'warrior2' 'warrior2' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank' 'plank'
#  'plank' 'plank' 'plank' 'plank' 'plank']
# 0.8116883116883117

# %%
import pickle

filename = 'finalmodel.sav'
pickle.dump(model, open(filename, 'wb'))
